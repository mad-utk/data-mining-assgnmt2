# %%
# install pycaret
# !pip install pycaret

# %%
# check installed version
import pycaret
pycaret.__version__
# Out:
# '3.0.4'

# %%
# import pycaret classification
from pycaret.classification import *

# %%
# mount google drive
from google.colab import drive
drive.mount("/content/gdrive")
drug_path = '/content/gdrive/MyDrive/Sem-I/CMPE-255 Data Mining/Assignments2/drug_detaset.csv'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# read data
import pandas as pd
drug_class = pd.read_csv(drug_path)

# check data
drug_class.shape
# Out:
# (200, 6)

# %%
drug_class.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
# create train data
data_train = drug_class.sample(frac=0.9)
data_train.shape
# Out:
# (180, 6)

# %%
data_train.head()
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 16    69   M     LOW      NORMAL   11.455  drugX
# 94    56   M     LOW        HIGH   15.015  DrugY
# 185   57   F  NORMAL      NORMAL   25.893  DrugY
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 152   55   M  NORMAL      NORMAL    7.261  drugX

# %%
data_test = drug_class.drop(data_train.index)
data_test.shape
# Out:
# (20, 6)

# %%
data_test.head()
# Out:
#     Age Sex   BP Cholesterol  Na_to_K   Drug
# 1    47   M  LOW        HIGH   13.093  drugC
# 2    47   M  LOW        HIGH   10.114  drugC
# 4    61   F  LOW        HIGH   18.043  DrugY
# 7    41   M  LOW        HIGH   11.037  drugC
# 12   43   M  LOW        HIGH   15.376  DrugY

# %%
data_train.reset_index(drop=True, inplace=True)
data_train.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   69   M     LOW      NORMAL   11.455  drugX
# 1   56   M     LOW        HIGH   15.015  DrugY
# 2   57   F  NORMAL      NORMAL   25.893  DrugY
# 3   23   M  NORMAL      NORMAL   14.020  drugX
# 4   55   M  NORMAL      NORMAL    7.261  drugX

# %%
data_test.reset_index(drop=True, inplace=True)
data_test.head()
# Out:
#    Age Sex   BP Cholesterol  Na_to_K   Drug
# 0   47   M  LOW        HIGH   13.093  drugC
# 1   47   M  LOW        HIGH   10.114  drugC
# 2   61   F  LOW        HIGH   18.043  DrugY
# 3   41   M  LOW        HIGH   11.037  drugC
# 4   43   M  LOW        HIGH   15.376  DrugY

# %%
s = setup(data_train, target = 'Drug')
# Out:
# <style type="text/css">
# #T_2cad6_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2cad6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cad6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2cad6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cad6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2cad6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2cad6_row0_col1" class="data row0 col1" >7366</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2cad6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2cad6_row1_col1" class="data row1 col1" >Drug</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2cad6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2cad6_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2cad6_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_2cad6_row3_col1" class="data row3 col1" >DrugY: 0, drugA: 1, drugB: 2, drugC: 3, drugX: 4</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2cad6_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_2cad6_row4_col1" class="data row4 col1" >(180, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2cad6_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_2cad6_row5_col1" class="data row5 col1" >(180, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2cad6_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_2cad6_row6_col1" class="data row6 col1" >(125, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2cad6_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_2cad6_row7_col1" class="data row7 col1" >(55, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2cad6_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_2cad6_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2cad6_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_2cad6_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2cad6_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_2cad6_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2cad6_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_2cad6_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2cad6_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_2cad6_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2cad6_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_2cad6_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2cad6_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_2cad6_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2cad6_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_2cad6_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2cad6_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_2cad6_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2cad6_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_2cad6_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2cad6_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_2cad6_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2cad6_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_2cad6_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2cad6_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_2cad6_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2cad6_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_2cad6_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2cad6_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_2cad6_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2cad6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_2cad6_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_2cad6_row23_col1" class="data row23 col1" >5eaf</td>
#     </tr>
#   </tbody>
# </table>

# %%
# compare baseline models
best = compare_models()
# Out:
# <style type="text/css">
# #T_802a6 th {
#   text-align: left;
# }
# #T_802a6_row0_col0, #T_802a6_row1_col0, #T_802a6_row2_col0, #T_802a6_row3_col0, #T_802a6_row4_col0, #T_802a6_row5_col0, #T_802a6_row5_col1, #T_802a6_row5_col2, #T_802a6_row5_col3, #T_802a6_row5_col4, #T_802a6_row5_col5, #T_802a6_row5_col6, #T_802a6_row5_col7, #T_802a6_row6_col0, #T_802a6_row6_col1, #T_802a6_row6_col2, #T_802a6_row6_col3, #T_802a6_row6_col4, #T_802a6_row6_col5, #T_802a6_row6_col6, #T_802a6_row6_col7, #T_802a6_row7_col0, #T_802a6_row7_col1, #T_802a6_row7_col2, #T_802a6_row7_col3, #T_802a6_row7_col4, #T_802a6_row7_col5, #T_802a6_row7_col6, #T_802a6_row7_col7, #T_802a6_row8_col0, #T_802a6_row8_col1, #T_802a6_row8_col2, #T_802a6_row8_col3, #T_802a6_row8_col4, #T_802a6_row8_col5, #T_802a6_row8_col6, #T_802a6_row8_col7, #T_802a6_row9_col0, #T_802a6_row9_col1, #T_802a6_row9_col2, #T_802a6_row9_col3, #T_802a6_row9_col4, #T_802a6_row9_col5, #T_802a6_row9_col6, #T_802a6_row9_col7, #T_802a6_row10_col0, #T_802a6_row10_col1, #T_802a6_row10_col2, #T_802a6_row10_col3, #T_802a6_row10_col4, #T_802a6_row10_col5, #T_802a6_row10_col6, #T_802a6_row10_col7, #T_802a6_row11_col0, #T_802a6_row11_col1, #T_802a6_row11_col2, #T_802a6_row11_col3, #T_802a6_row11_col4, #T_802a6_row11_col5, #T_802a6_row11_col6, #T_802a6_row11_col7, #T_802a6_row12_col0, #T_802a6_row12_col1, #T_802a6_row12_col2, #T_802a6_row12_col3, #T_802a6_row12_col4, #T_802a6_row12_col5, #T_802a6_row12_col6, #T_802a6_row12_col7, #T_802a6_row13_col0, #T_802a6_row13_col1, #T_802a6_row13_col2, #T_802a6_row13_col3, #T_802a6_row13_col4, #T_802a6_row13_col5, #T_802a6_row13_col6, #T_802a6_row13_col7, #T_802a6_row14_col0, #T_802a6_row14_col1, #T_802a6_row14_col2, #T_802a6_row14_col3, #T_802a6_row14_col4, #T_802a6_row14_col5, #T_802a6_row14_col6, #T_802a6_row14_col7 {
#   text-align: left;
# }
# #T_802a6_row0_col1, #T_802a6_row0_col2, #T_802a6_row0_col3, #T_802a6_row0_col4, #T_802a6_row0_col5, #T_802a6_row0_col6, #T_802a6_row0_col7, #T_802a6_row1_col1, #T_802a6_row1_col2, #T_802a6_row1_col3, #T_802a6_row1_col4, #T_802a6_row1_col5, #T_802a6_row1_col6, #T_802a6_row1_col7, #T_802a6_row2_col1, #T_802a6_row2_col2, #T_802a6_row2_col3, #T_802a6_row2_col4, #T_802a6_row2_col5, #T_802a6_row2_col6, #T_802a6_row2_col7, #T_802a6_row3_col1, #T_802a6_row3_col2, #T_802a6_row3_col3, #T_802a6_row3_col4, #T_802a6_row3_col5, #T_802a6_row3_col6, #T_802a6_row3_col7, #T_802a6_row4_col1, #T_802a6_row4_col2, #T_802a6_row4_col3, #T_802a6_row4_col4, #T_802a6_row4_col5, #T_802a6_row4_col6, #T_802a6_row4_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_802a6_row0_col8, #T_802a6_row1_col8, #T_802a6_row2_col8, #T_802a6_row3_col8, #T_802a6_row4_col8, #T_802a6_row5_col8, #T_802a6_row6_col8, #T_802a6_row7_col8, #T_802a6_row8_col8, #T_802a6_row9_col8, #T_802a6_row11_col8, #T_802a6_row12_col8, #T_802a6_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_802a6_row10_col8, #T_802a6_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_802a6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_802a6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_802a6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_802a6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_802a6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_802a6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_802a6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_802a6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_802a6_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_802a6_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_802a6_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_802a6_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_802a6_row0_col1" class="data row0 col1" >0.9923</td>
#       <td id="T_802a6_row0_col2" class="data row0 col2" >0.8000</td>
#       <td id="T_802a6_row0_col3" class="data row0 col3" >0.9923</td>
#       <td id="T_802a6_row0_col4" class="data row0 col4" >0.9949</td>
#       <td id="T_802a6_row0_col5" class="data row0 col5" >0.9918</td>
#       <td id="T_802a6_row0_col6" class="data row0 col6" >0.9892</td>
#       <td id="T_802a6_row0_col7" class="data row0 col7" >0.9899</td>
#       <td id="T_802a6_row0_col8" class="data row0 col8" >0.2800</td>
#     </tr>
#     <tr>
#       <th id="T_802a6_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_802a6_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_802a6_row1_col1" class="data row1 col1" >0.9923</td>
#       <td id="T_802a6_row1_col2" class="data row1 col2" >0.8000</td>
#       <td id="T_802a6_row1_col3" class="data row1 col3" >0.9923</td>
#       <td id="T_802a6_row1_col4" class="data row1 col4" >0.9949</td>
#       <td id="T_802a6_row1_col5" class="data row1 col5" >0.9918</td>
#       <td id="T_802a6_row1_col6" class="data row1 col6" >0.9892</td>
#       <td id="T_802a6_row1_col7" class="data row1 col7" >0.9899</td>
#       <td id="T_802a6_row1_col8" class="data row1 col8" >0.5290</td>
#     </tr>
#     <tr>
#       <th id="T_802a6_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_802a6_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_802a6_row2_col1" class="data row2 col1" >0.9923</td>
#       <td id="T_802a6_row2_col2" class="data row2 col2" >0.8000</td>
#       <td id="T_802a6_row2_col3" class="data row2 col3" >0.9923</td>
#       <td id="T_802a6_row2_col4" class="data row2 col4" >0.9949</td>
#       <td id="T_802a6_row2_col5" class="data row2 col5" >0.9918</td>
#       <td id="T_802a6_row2_col6" class="data row2 col6" >0.9892</td>
#       <td id="T_802a6_row2_col7" class="data row2 col7" >0.9899</td>
#       <td id="T_802a6_row2_col8" class="data row2 col8" >1.1410</td>
#     </tr>
#     <tr>
#       <th id="T_802a6_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_802a6_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_802a6_row3_col1" class="data row3 col1" >0.9923</td>
#       <td id="T_802a6_row3_col2" class="data row3 col2" >0.8000</td>
#       <td id="T_802a6_row3_col3" class="data row3 col3" >0.9923</td>
#       <td id="T_802a6_row3_col4" class="data row3 col4" >0.9949</td>
#       <td id="T_802a6_row3_col5" class="data row3 col5" >0.9918</td>
#       <td id="T_802a6_row3_col6" class="data row3 col6" >0.9892</td>
#       <td id="T_802a6_row3_col7" class="data row3 col7" >0.9899</td>
#       <td id="T_802a6_row3_col8" class="data row3 col8" >0.2740</td>
#     </tr>
#     <tr>
#       <th id="T_802a6_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_802a6_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_802a6_row4_col1" class="data row4 col1" >0.9923</td>
#       <td id="T_802a6_row4_col2" class="data row4 col2" >0.8000</td>
#       <td id="T_802a6_row4_col3" class="data row4 col3" >0.9923</td>
#       <td id="T_802a6_row4_col4" class="data row4 col4" >0.9949</td>
#       <td id="T_802a6_row4_col5" class="data row4 col5" >0.9918</td>
#       <td id="T_802a6_row4_col6" class="data row4 col6" >0.9892</td>
#       <td id="T_802a6_row4_col7" class="data row4 col7" >0.9899</td>
#       <td id="T_802a6_row4_col8" class="data row4 col8" >0.7620</td>
#     </tr>
#     <tr>
#       <th id="T_802a6_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_802a6_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_802a6_row5_col1" class="data row5 col1" >0.9763</td>
#       <td id="T_802a6_row5_col2" class="data row5 col2" >0.7991</td>
#       <td id="T_802a6_row5_col3" class="data row5 col3" >0.9763</td>
#       <td id="T_802a6_row5_col4" class="data row5 col4" >0.9764<
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
# plot confusion matrix
plot_model(best, plot = 'confusion_matrix')

# %%
# plot AUC
plot_model(best, plot = 'auc')

# %%
# plot feature importance
plot_model(best, plot = 'feature')

# %%
rf_classifier = create_model('rf')
# Out:
# <style type="text/css">
# #T_81252_row10_col0, #T_81252_row10_col1, #T_81252_row10_col2, #T_81252_row10_col3, #T_81252_row10_col4, #T_81252_row10_col5, #T_81252_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_81252" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81252_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_81252_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_81252_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_81252_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_81252_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_81252_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_81252_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81252_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81252_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_81252_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_81252_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_81252_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_81252_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_81252_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_81252_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81252_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_81252_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_81252_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_81252_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_81252_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_81252_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_81252_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_81252_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_81252_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_81252_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_81252_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_81252_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_81252_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_81252_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_81252_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_81252_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_81252_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_81252_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_81252_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_81252_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_81252_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_81252_row4_col0" class="data row4 col0" >0.9231</td>
#       <td id="T_81252_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_81252_row4_col2" class="data row4 col2" >0.9231</td>
#       <td id="T_81252_row4_col3" class="data row4 col3" >0.9487</td>
#       <td id="T_81252_row4_col4" class="data row4 col4" >0.9179</td>
#       <td id="T_81252_row4_col5" class="data row4 col5" >0.8917</td>
#       <td id="T_81252_row4_col6" class="data row4 col6" >0.8992</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_81252_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_81252_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_81252_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_81252_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_81252_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_81252_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_81252_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_81252_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_81252_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_81252_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_81252_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_81252_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_81252_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_81252_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_81252_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_81252_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_81252_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_81252_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_81252_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_81252_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_81252_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_81252_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_81252_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_81252_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_81252_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_81252_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_81252_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_81252_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_81252_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_81252_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_81252_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_81252_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_81252_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_81252_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_81252_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_81252_row10_col0" class="data row10 col0" >0.9923</td>
#       <td id="T_81252_row10_col1" class="data row10 col1" >0.8000</td>
#       <td id="T_81252_row10_col2" class="data row10 col2" >0.9923</td>
#       <td id="T_81252_row10_col3" class="data row10 col3" >0.9949</td>
#       <td id="T_81252_row10_col4" class="data row10 col4" >0.9918</td>
#       <td id="T_81252_row10_col5" class="data row10 col5" >0.9892</td>
#       <td id="T_81252_row10_col6" class="data row10 col6" >0.9899</td>
#     </tr>
#     <tr>
#       <th id="T_81252_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_81252_row11_col0" class="data row11 col0" >0.0231</td>
#       <td id="T_81252_row11_col1" class="data row11 col1" >0.4000</td>
#       <td id="T_81252_row11_col2" class="data row11 col2" >0.0231</td>
#       <td id="T_81252_row11_col3" class="data row11 col3" >0.0154</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
print(rf_classifier)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=7366, verbose=0, warm_start=False)

# %%
tuned_rf_classifier=tune_model(rf_classifier)
# Out:
# <style type="text/css">
# #T_9d409_row10_col0, #T_9d409_row10_col1, #T_9d409_row10_col2, #T_9d409_row10_col3, #T_9d409_row10_col4, #T_9d409_row10_col5, #T_9d409_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9d409" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d409_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9d409_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9d409_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9d409_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9d409_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9d409_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9d409_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d409_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d409_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_9d409_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_9d409_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_9d409_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_9d409_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_9d409_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_9d409_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d409_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_9d409_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_9d409_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_9d409_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_9d409_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_9d409_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_9d409_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d409_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_9d409_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_9d409_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_9d409_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_9d409_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_9d409_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_9d409_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d409_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_9d409_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_9d409_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_9d409_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_9d409_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_9d409_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_9d409_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d409_row4_col0" class="data row4 col0" >0.9231</td>
#       <td id="T_9d409_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_9d409_row4_col2" class="data row4 col2" >0.9231</td>
#       <td id="T_9d409_row4_col3" class="data row4 col3" >0.9487</td>
#       <td id="T_9d409_row4_col4" class="data row4 col4" >0.9179</td>
#       <td id="T_9d409_row4_col5" class="data row4 col5" >0.8917</td>
#       <td id="T_9d409_row4_col6" class="data row4 col6" >0.8992</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9d409_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_9d409_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_9d409_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_9d409_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_9d409_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_9d409_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_9d409_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9d409_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_9d409_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_9d409_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_9d409_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_9d409_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_9d409_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_9d409_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9d409_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_9d409_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_9d409_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_9d409_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_9d409_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_9d409_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_9d409_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9d409_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_9d409_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_9d409_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_9d409_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_9d409_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_9d409_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_9d409_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9d409_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_9d409_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_9d409_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_9d409_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_9d409_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_9d409_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_9d409_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9d409_row10_col0" class="data row10 col0" >0.9923</td>
#       <td id="T_9d409_row10_col1" class="data row10 col1" >0.8000</td>
#       <td id="T_9d409_row10_col2" class="data row10 col2" >0.9923</td>
#       <td id="T_9d409_row10_col3" class="data row10 col3" >0.9949</td>
#       <td id="T_9d409_row10_col4" class="data row10 col4" >0.9918</td>
#       <td id="T_9d409_row10_col5" class="data row10 col5" >0.9892</td>
#       <td id="T_9d409_row10_col6" class="data row10 col6" >0.9899</td>
#     </tr>
#     <tr>
#       <th id="T_9d409_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9d409_row11_col0" class="data row11 col0" >0.0231</td>
#       <td id="T_9d409_row11_col1" class="data row11 col1" >0.4000</td>
#       <td id="T_9d409_row11_col2" class="data row11 col2" >0.0231</td>
#       <td id="T_9d409_row11_col3" class="data row11 col3" >0.0154</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
print(tuned_rf_classifier)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=7366, verbose=0, warm_start=False)

# %%
plot_model(tuned_rf_classifier, plot="class_report")

# %%
plot_model(tuned_rf_classifier, plot="error")

# %%
evaluate_model(tuned_rf_classifier)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# save pipeline
final_rf = finalize_model(tuned_rf_classifier)
print(final_rf)
# Out:
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None, include=['Age', 'Na_to_K'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='gini',
#                                         max_depth=None, max_features='sqrt',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=-1,
#                                         oob_score=False, random_state=7366,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
test_prediction = predict_model(final_rf, data=data_test)
test_prediction.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a47a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a47a4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a47a4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a47a4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a47a4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a47a4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a47a4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a47a4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a47a4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a47a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a47a4_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_a47a4_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_a47a4_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a47a4_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_a47a4_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_a47a4_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_a47a4_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_a47a4_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
#    Age Sex   BP Cholesterol    Na_to_K  Drug prediction_label  \
# 0   47   M  LOW        HIGH  13.093000     3            drugC
# 1   47   M  LOW        HIGH  10.114000     3            drugC
# 2   61   F  LOW        HIGH  18.042999     0            DrugY
# 3   41   M  LOW        HIGH  11.037000     3            drugC
# 4   43   M  LOW        HIGH  15.376000     0            DrugY
#
#    prediction_score
# 0              0.74
# 1              0.82
# 2              0.92
# 3              0.70
# 4              0.97
