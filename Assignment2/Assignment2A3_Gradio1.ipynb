# %%
# install pycaret
# !pip install pycaret
# gradio app
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 51.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 65.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.9 MB/s eta 0:00:00
# ...

# %%
# check installed version
import pycaret
pycaret.__version__
# Out:
# '3.1.0'

# %%
# mount google drive
from google.colab import drive
drive.mount("/content/gdrive")
crab_age_path = '/content/gdrive/MyDrive/Sem-I/CMPE-255 Data Mining/Assignments2/CrabAgePrediction.csv'
# Out:
# Mounted at /content/gdrive

# %%
# read data
import pandas as pd
crab_age_regression = pd.read_csv(crab_age_path)

# check data
crab_age_regression.shape
# Out:
# (3893, 9)

# %%
# import pycaret regression and init setup
from pycaret.regression import *
reg = setup(crab_age_regression, target = 'Age', session_id = 333)
# Out:
# <style type="text/css">
# #T_7ed68_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7ed68" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ed68_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7ed68_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ed68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ed68_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7ed68_row0_col1" class="data row0 col1" >333</td>
#     </tr>
#     <tr>
#       <th id="T_7ed68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ed68_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7ed68_row1_col1" class="data row1 col1" >Age</td>
#     </tr>
#     <tr>
#       <th id="T_7ed68_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
gbr_regressor = create_model('gbr')
# Out:
# <style type="text/css">
# #T_1262d_row10_col0, #T_1262d_row10_col1, #T_1262d_row10_col2, #T_1262d_row10_col3, #T_1262d_row10_col4, #T_1262d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1262d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1262d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1262d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1262d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1262d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1262d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1262d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(gbr_regressor)
# Out:
# GradientBoostingRegressor(random_state=333)

# %%
create_app(gbr_regressor)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %%
save_model(gbr_regressor, "my_gradio1_model")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Length', 'Diameter', 'Height',
#                                               'Weight', 'Shucked Weight',
#                                               'Viscera Weight', 'Shell Weight'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Sex'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['Sex'],
#                                      transformer=OneHotEncoder(cols=['Sex'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
# ...
